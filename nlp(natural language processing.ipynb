# %%
import sqlite3
import numpy as np
import pandas as pd

# %%
conn=sqlite3.connect("C:/Users/ADMIN/Downloads/database.sqlite")

# %%
conn

# %%
filtered_data=pd.read_sql_query(""" select * from reviews""",conn)

# %%
filtered_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
filtered_data=pd.read_sql_query("""select * from reviews where Score!=3""",conn)

# %%
filtered_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
def new_category(x):
    if x<3:
        return "Negitive"
    else:
        return "Positive"

# %%
filtered_data["score"]=filtered_data["Score"].apply(new_category)

# %%
filterddata
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
filtered_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
filtered_data.drop(columns=["Score"],inplace=True)

# %%
filtered_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
display=pd.read_sql_query("""select * from reviews where UserId like 'AR%'""",conn)

# %%
display
# Out:
#           Id   ProductId         UserId               ProfileName  \
# 0         23  B001GVISJM  ARYVQL4N737A1             Charles Brown
# 1        141  B001GVISJW  ARS5Q7LR6HWPG           N. Pine "pcone"
# 2        165  B000ITVLE2  ARTBQH9WOZTIV   Billy Wilson "amzrview"
# 3        295  B001UJEN6C  AREOHWLWVX0A8              John Erikson
# 4        411  B0089PI9OC  ARYNM1E978YX8                      Bill
# ...      ...         ...            ...                       ...
# 4336  567350  B000LKTP9G  ARSNLI5L2P5RL           Rebecca Quinlan
# 4337  567601  B005K4Q68Q  ARWRBORADGA3G  Ryan White "SunsetQuest"
# 4338  567843  B005K4Q68Q  ARAKTT5M3DDYA                    JustMe
# 4339  568112  B000NY4SA6  ARVPXWNWIRBK1            Timithie Gould
# 4340  568263  B00374ZKQ0  ARFV8BBMBQ054          Sensitive Palate
#
#       HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                        0                       0      5  1304899200
# ...

# %%
display
# Out:
#           Id   ProductId         UserId               ProfileName  \
# 0         23  B001GVISJM  ARYVQL4N737A1             Charles Brown
# 1        141  B001GVISJW  ARS5Q7LR6HWPG           N. Pine "pcone"
# 2        165  B000ITVLE2  ARTBQH9WOZTIV   Billy Wilson "amzrview"
# 3        295  B001UJEN6C  AREOHWLWVX0A8              John Erikson
# 4        411  B0089PI9OC  ARYNM1E978YX8                      Bill
# ...      ...         ...            ...                       ...
# 4336  567350  B000LKTP9G  ARSNLI5L2P5RL           Rebecca Quinlan
# 4337  567601  B005K4Q68Q  ARWRBORADGA3G  Ryan White "SunsetQuest"
# 4338  567843  B005K4Q68Q  ARAKTT5M3DDYA                    JustMe
# 4339  568112  B000NY4SA6  ARVPXWNWIRBK1            Timithie Gould
# 4340  568263  B00374ZKQ0  ARFV8BBMBQ054          Sensitive Palate
#
#       HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                        0                       0      5  1304899200
# ...

# %%
display1=pd.read_sql_query("""select * from reviews where UserId like '%CURR'""",conn)

# %%
display1
# Out:
#        Id   ProductId         UserId      ProfileName  HelpfulnessNumerator  \
# 0   73791  B000HDOPZG  AR5J8UI46CURR  Geetha Krishnan                     2
# 1   78445  B000HDL1RQ  AR5J8UI46CURR  Geetha Krishnan                     2
# 2  138277  B000HDOPYM  AR5J8UI46CURR  Geetha Krishnan                     2
# 3  138317  B000HDOPYC  AR5J8UI46CURR  Geetha Krishnan                     2
# 4  155049  B000PAQ75C  AR5J8UI46CURR  Geetha Krishnan                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       2      5  1199577600
# 1                       2      5  1199577600
# 2                       2      5  1199577600
# 3                       2      5  1199577600
# 4                       2      5  1199577600
#
#                              Summary  \
# 0  LOACKER QUADRATINI VANILLA WAFERS
# 1  LOACKER QUADRATINI VANILLA WAFERS
# 2  LOACKER QUADRATINI VANILLA WAFERS
# 3  LOACKER QUADRATINI VANILLA WAFERS
# 4  LOACKER QUADRATINI VANILLA WAFERS
#
# ...

# %%
display3=pd.read_sql_query("""select * from reviews where 'UserId'=='AR5J8UI46CURR' order by ProductId""",conn)

# %%
display3
# Out:
# Empty DataFrame
# Columns: [Id, ProductId, UserId, ProfileName, HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary, Text]
# Index: []

# %%
filtered_data.drop_duplicates(subset={"UserId","ProfileName","Time","Summary","Text"},keep='first',inplace=True)

# %%
filtered_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
final_data=filtered_data[filtered_data["HelpfulnessNumerator"]<=filtered_data["HelpfulnessDenominator"]]

# %%
filtered_data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
final_data.shape
# Out:
# (365331, 10)

# %%
final_data["score"].value_counts()
# Out:
# score
# Positive    307967
# Negitive     57364
# Name: count, dtype: int64

# %%
test="""<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>GFG </title>
</head>
<body>
    <a href="https://www.geeksforgeeks.org/">Geeks For Geeks</a>
    <a href="Dummy Check Text">Geeks For Geeks</a>
    <a href="Dummywebsite.com">Dummy Text</a>

    <h1>Hello</h1>
    <h1>Python Program</h1>"""

# %%
test
# Out:
# '<html lang="en">\n<head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <title>GFG </title>\n</head>\n<body>\n    <a href="https://www.geeksforgeeks.org/">Geeks For Geeks</a>\n    <a href="Dummy Check Text">Geeks For Geeks</a>\n    <a href="Dummywebsite.com">Dummy Text</a>\n\n    <h1>Hello</h1>\n    <h1>Python Program</h1>'

# %% [markdown]
# ## 02/07/2025:

# %%
s=5

# %%
s
# Out:
# 5

# %%
s="mayur"

# %%
r=s.encode('utf-8')

# %%
r
# Out:
# b'mayur'

# %%
type(r)
# Out:
# bytes

# %%
bin(r[0])
# Out:
# '0b1101101'
