# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data=df['PetalLengthCm']

# %%
data
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
result=stats.anderson(data,dist='norm')

# %%
result
# Out:
# AndersonResult(statistic=7.672882599382774, critical_values=array([0.562, 0.64 , 0.767, 0.895, 1.065]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=3.758666666666666, scale=1.7644204199522617)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
result.critical_values
# Out:
# array([0.562, 0.64 , 0.767, 0.895, 1.065])

# %%
result.statistic
# Out:
# 7.672882599382774

# %%
result.significance_level
# Out:
# array([15. , 10. ,  5. ,  2.5,  1. ])

# %%
data
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
normilized_data=((data-np.mean(data))/np.std(data))

# %%
normilized_data
# Out:
# 0     -1.341272
# 1     -1.341272
# 2     -1.398138
# 3     -1.284407
# 4     -1.341272
#          ...
# 145    0.819624
# 146    0.705893
# 147    0.819624
# 148    0.933356
# 149    0.762759
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
stats_par,p_value=stats.kstest(normilized_data,'norm')

# %%
stats_par
# Out:
# 0.19913533995975125

# %%
p_value
# Out:
# 1.0900352050591355e-05

# %%
transform_data,alpha=stats.boxcox(data)

# %%
transform_data
# Out:
# array([0.39515619, 0.39515619, 0.29719529, 0.4926371 , 0.39515619,
#        0.68629123, 0.39515619, 0.4926371 , 0.39515619, 0.4926371 ,
#        0.4926371 , 0.58967219, 0.39515619, 0.09966812, 0.19871477,
#        0.4926371 , 0.29719529, 0.39515619, 0.68629123, 0.4926371 ,
#        0.68629123, 0.4926371 , 0.        , 0.68629123, 0.87838265,
#        0.58967219, 0.58967219, 0.4926371 , 0.39515619, 0.58967219,
#        0.58967219, 0.4926371 , 0.4926371 , 0.39515619, 0.4926371 ,
#        0.19871477, 0.29719529, 0.4926371 , 0.29719529, 0.4926371 ,
#        0.29719529, 0.29719529, 0.29719529, 0.58967219, 0.87838265,
#        0.39515619, 0.58967219, 0.39515619, 0.4926371 , 0.39515619,
#        3.46390962, 3.28381618, 3.64347714, 2.83111139, 3.37393015,
#        3.28381618, 3.46390962, 2.19061771, 3.37393015, 2.74011759,
#        2.37449134, 3.01263452, 2.83111139, 3.46390962, 2.46615512,
#        3.19356452, 3.28381618, 2.92194901, 3.28381618, 2.74011759,
# ...

# %%
import matplotlib.pyplot as plt

# %%
stats.probplot(transform_data,dist='norm',plot=plt)
# Out:
# ((array([-2.60376328, -2.283875  , -2.1005573 , -1.96875864, -1.86428437,
#          -1.77691182, -1.70131573, -1.63435332, -1.57400778, -1.51890417,
#          -1.46806125, -1.42075308, -1.37642684, -1.33465133, -1.29508341,
#          -1.25744533, -1.22150891, -1.18708433, -1.15401181, -1.12215558,
#          -1.0913992 , -1.06164202, -1.03279638, -1.00478546, -0.97754152,
#          -0.95100448, -0.92512081, -0.89984257, -0.87512664, -0.85093408,
#          -0.8272296 , -0.80398107, -0.78115919, -0.75873709, -0.73669013,
#          -0.71499557, -0.69363244, -0.67258128, -0.65182406, -0.63134396,
#          -0.61112532, -0.59115349, -0.57141472, -0.55189613, -0.53258558,
#          -0.51347162, -0.49454346, -0.47579085, -0.45720409, -0.43877397,
#          -0.4204917 , -0.40234892, -0.38433762, -0.36645016, -0.3486792 ,
#          -0.33101768, -0.31345882, -0.29599609, -0.27862316, -0.26133393,
#          -0.24412247, -0.22698303, -0.20991002, -0.19289797, -0.17594158,
# ...

# %%
alpha
# Out:
# 0.9312952288705908

# %%
transform_data
# Out:
# array([0.39515619, 0.39515619, 0.29719529, 0.4926371 , 0.39515619,
#        0.68629123, 0.39515619, 0.4926371 , 0.39515619, 0.4926371 ,
#        0.4926371 , 0.58967219, 0.39515619, 0.09966812, 0.19871477,
#        0.4926371 , 0.29719529, 0.39515619, 0.68629123, 0.4926371 ,
#        0.68629123, 0.4926371 , 0.        , 0.68629123, 0.87838265,
#        0.58967219, 0.58967219, 0.4926371 , 0.39515619, 0.58967219,
#        0.58967219, 0.4926371 , 0.4926371 , 0.39515619, 0.4926371 ,
#        0.19871477, 0.29719529, 0.4926371 , 0.29719529, 0.4926371 ,
#        0.29719529, 0.29719529, 0.29719529, 0.58967219, 0.87838265,
#        0.39515619, 0.58967219, 0.39515619, 0.4926371 , 0.39515619,
#        3.46390962, 3.28381618, 3.64347714, 2.83111139, 3.37393015,
#        3.28381618, 3.46390962, 2.19061771, 3.37393015, 2.74011759,
#        2.37449134, 3.01263452, 2.83111139, 3.46390962, 2.46615512,
#        3.19356452, 3.28381618, 2.92194901, 3.28381618, 2.74011759,
# ...

# %% [markdown]
# ## 30/05/2025:

# %%
import numpy as np
import pandas as pd
from scipy.stats  import chi2_contingency

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Survived','Pclass']].dropna()
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %%
survived_0=[
    len(df[(df['Survived']==0)&(df['Pclass']==1)]),
    len(df[(df['Survived']==0)&(df['Pclass']==2)]),
    len(df[(df['Survived']==0)&(df['Pclass']==3)])
]
survived_1=[
           len(df[(df['Survived']==1)&(df['Pclass']==1)]),
           len(df[(df['Survived']==1)&(df['Pclass']==2)]),
           len(df[(df['Survived']==1)&(df['Pclass']==3)])]

# %%
observed=np.array([survived_0,survived_1])

# %%
observed
# Out:
# array([[ 80,  97, 372],
#        [136,  87, 119]])

# %%
chi2,p,dof,expected=chi2_contingency(observed)

# %%
chi2
# Out:
# 102.88898875696056

# %%
p
# Out:
# 4.549251711298793e-23

# %%
dof
# Out:
# 2

# %%
expected
# Out:
# array([[133.09090909, 113.37373737, 302.53535354],
#        [ 82.90909091,  70.62626263, 188.46464646]])

# %% [markdown]
# ## 31/05/2025:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv('marketing_cva_f.csv')

# %%
df
# Out:
#      Customer       State           CLV  Coverage  Income  loc_type  \
# 0     BU79786  Washington   2763.519279     Basic   56274  Suburban
# 1     AI49188      Nevada  12887.431650   Premium   48767  Suburban
# 2     HB64268  Washington   2813.692575     Basic   43836     Rural
# 3     OC83172      Oregon   8256.297800     Basic   62902     Rural
# 4     XZ87318      Oregon   5380.898636     Basic   55350  Suburban
# ...       ...         ...           ...       ...     ...       ...
# 6812  TF56202  California   5032.165498     Basic   66367  Suburban
# 6813  YM19146  California   4100.398533   Premium   47761  Suburban
# 6814  LA72316  California  23405.987980     Basic   71941     Urban
# 6815  PK87824  California   3096.511217  Extended   21604  Suburban
# 6816  UP19263  California   7524.442436  Extended   21941  Suburban
#
#       monthly_premium  months_last_claim  Months_Since_Policy_Inception  \
# 0                  69                 32                              5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6817 entries, 0 to 6816
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       6817 non-null   object
#  1   State                          6817 non-null   object
#  2   CLV                            6817 non-null   float64
#  3   Coverage                       6817 non-null   object
#  4   Income                         6817 non-null   int64
#  5   loc_type                       6817 non-null   object
#  6   monthly_premium                6817 non-null   int64
#  7   months_last_claim              6817 non-null   int64
#  8   Months_Since_Policy_Inception  6817 non-null   int64
#  9   Total_Claim_Amount             6817 non-null   float64
#  10  Vehicle_Class                  6817 non-null   object
#  11  avg_vehicle_age                6817 non-null   float64
# ...

# %%
df['avg_vehicle_age']
# Out:
# 0       40.696695
# 1       48.755298
# 2       70.394474
# 3       53.460212
# 4       32.811507
#           ...
# 6812    37.492591
# 6813    48.946675
# 6814    65.310053
# 6815    48.002914
# 6816    45.151858
# Name: avg_vehicle_age, Length: 6817, dtype: float64

# %%
df['avg_vehicle_age'].isnull().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 CLV        Income  monthly_premium  months_last_claim  \
# count   6817.000000   6817.000000      6817.000000        6817.000000
# mean    8130.229340  50456.580461        92.963034          15.046941
# std     6949.067972  24305.956566        34.615160          10.064762
# min     2119.894333  10037.000000        61.000000           0.000000
# 25%     4090.750678  28432.000000        68.000000           6.000000
# 50%     5810.630529  48081.000000        83.000000          14.000000
# 75%     9075.768214  70187.000000       109.000000          23.000000
# max    83325.381190  99981.000000       297.000000          35.000000
#
#        Months_Since_Policy_Inception  Total_Claim_Amount  avg_vehicle_age
# count                    6817.000000         6817.000000      6817.000000
# mean                       47.832624          377.840789        50.126257
# std                        27.895350          252.648952         9.919767
# ...

# %%
#distribution plot for normality
sns.distplot(df['avg_vehicle_age'],hist=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19708\669886769.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['avg_vehicle_age'],hist=True)
# <Axes: xlabel='avg_vehicle_age', ylabel='Density'>

# %%
stats.probplot(df['avg_vehicle_age'],dist='norm',plot=plt)
# Out:
# ((array([-3.71482038, -3.48420977, -3.35734064, ...,  3.35734064,
#           3.48420977,  3.71482038]),
#   array([11.87597393, 12.97579736, 13.65700265, ..., 81.36779223,
#          83.20637063, 83.38748475])),
#  (9.922473086072275, 50.12625675651166, 0.9998408439831585))

# %%
tranform_data,l=stats.boxcox(df['avg_vehicle_age'])

# %%
tranform_data
# Out:
# array([44.44389775, 53.83105166, 79.32549155, ..., 73.30260475,
#        52.95181483, 49.62516201])

# %%
l
# Out:
# 1.0401662897663373

# %%
stats.probplot(tranform_data,dist='norm',plot=plt)
# Out:
# ((array([-3.71482038, -3.48420977, -3.35734064, ...,  3.35734064,
#           3.48420977,  3.71482038]),
#   array([11.64910452, 12.86605405, 13.6219093 , ..., 92.38243043,
#          94.57732454, 94.79364462])),
#  (11.601764328160808, 55.48169774087039, 0.9998609791766202))

# %%
#H0:avg vehicle is gaussian distribution
#H1:avg vehicle is not gassian distribution
stats.anderson(df['avg_vehicle_age'],dist='norm')
# Out:
# AndersonResult(statistic=0.38327277704684093, critical_values=array([0.576, 0.656, 0.787, 0.917, 1.091]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=50.12625675651166, scale=9.919766709600536)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
# 1.test statistics
# 2.critical value
# 3.significance level:15%,10%,5%,2%,1%

# criteria:
# test statistics>=critical_value-
# NUll hypothesis is rejected---->alternative hypothesis is accepted
# test statistics<critical value--->null hypothesis is accepted

# In this case H0 accepted
# it is gaussian distribution

# %%
data=df["avg_vehicle_age"]

# %%
normalized_data=(data-(np.mean(data))/np.std(data))

# %%
normalized_data
# Out:
# 0       35.643155
# 1       43.701758
# 2       65.340934
# 3       48.406672
# 4       27.757967
#           ...
# 6812    32.439052
# 6813    43.893135
# 6814    60.256513
# 6815    42.949374
# 6816    40.098319
# Name: avg_vehicle_age, Length: 6817, dtype: float64

# %%
stats.kstest(normalized_data,'norm')
# Out:
# KstestResult(statistic=0.9999999999955245, pvalue=0.0, statistic_location=6.822434346725044, statistic_sign=-1)

# %%
sample_mean=[]
for i in range(1000):
    sample=np.random.choice(df["avg_vehicle_age"],size=30,replace=True)
    sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [48.655352676999996,
#  47.458279397000005,
#  52.453456005,
#  49.403918676,
#  46.72445891533333,
#  53.306070203,
#  46.48437832533333,
#  49.80299484833333,
#  52.53797049766667,
#  50.70957481933332,
#  51.411810213666655,
#  50.97849478133333,
#  53.867537683333325,
#  51.38885722066666,
#  47.36331470533334,
#  48.627304472333336,
#  47.06900229066666,
#  47.820004658666676,
#  50.09850789333335,
#  48.299128632333336,
#  50.025315184666674,
#  47.25039424433334,
#  52.573741971,
#  47.10544489133334,
#  48.05648817499999,
#  52.42148613766667,
#  53.12133956233333,
#  51.647896676333325,
#  48.12089572433333,
#  51.093665521333335,
#  50.57383858366667,
#  47.740916727,
#  49.04321368000001,
#  49.350207063666666,
#  50.861341093666674,
#  48.04725337700001,
#  52.01447803200001,
#  50.25551482333333,
#  50.397392637,
#  50.287813977,
#  53.60514546766667,
#  50.45246733299999,
#  51.200512917333334,
#  50.74333473433333,
#  47.297000819,
#  48.67073616066667,
# ...

# %%
sns.distplot(sample_mean,hist=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19708\13154297.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean,hist=True)
# <Axes: ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'CLV', 'Coverage', 'Income', 'loc_type',
#        'monthly_premium', 'months_last_claim', 'Months_Since_Policy_Inception',
#        'Total_Claim_Amount', 'Vehicle_Class', 'avg_vehicle_age'],
#       dtype='object')

# %% [markdown]
# df.head()

# %% [markdown]
# ## 02/06/2025:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df=df.dropna(subset=['Age','Survived'])

# %%
children=df[df['Age']<16]

# %%
adults=df[df['Age']>=16]

# %%
child_survival_rate=children['Survived'].mean()

# %%
adult_survival_rate=adults['Survived'].mean()

# %%
child_survival_rate
# Out:
# 0.5903614457831325

# %%
print(f"Child Survival Rate:{child_survival_rate:.2f}")
# Out:
# Child Survival Rate: 0.59

# %%
adult_survival_rate
# Out:
# 0.38193343898573695

# %%
print(f"Adult Survival Rate:{adult_survival_rate:.2f}")
# Out:
# Adult Survival Rate:0.38

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
z_stats,p_value=proportions_ztest(count='survived_matrix',norm
larger:s1 is greater than s2
