# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age']=(df['Age']-np.min(df['Age']))/(np.max(df['Age'])-np.min(df['Age']))

# %%
df['Age']
# Out:
# 0      0.271174
# 1      0.472229
# 2      0.321438
# 3      0.434531
# 4      0.434531
#          ...
# 886    0.334004
# 887    0.233476
# 888         NaN
# 889    0.321438
# 890    0.396833
# Name: Age, Length: 891, dtype: float64

# %%
x=MinMaxScaler()
df['Fare']=x.fit_transform(df[['Fare']])

# %%
df['Fare']
# Out:
# 0      0.014151
# 1      0.139136
# 2      0.015469
# 3      0.103644
# 4      0.015713
#          ...
# 886    0.025374
# 887    0.058556
# 888    0.045771
# 889    0.058556
# 890    0.015127
# Name: Fare, Length: 891, dtype: float64

# %%
df1=pd.read_csv('iris.csv')

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df1['PetalLengthCm']=(df1['PetalLengthCm']-np.mean(df1['PetalLengthCm']))/np.std(df1['PetalLengthCm'])

# %%
df1['PetalLengthCm']
# Out:
# 0     -1.341272
# 1     -1.341272
# 2     -1.398138
# 3     -1.284407
# 4     -1.341272
#          ...
# 145    0.819624
# 146    0.705893
# 147    0.819624
# 148    0.933356
# 149    0.762759
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
y=StandardScaler()
df1['PetalWidthCm']=y.fit_transform(df1[['PetalWidthCm']])

# %%
df1['PetalWidthCm']
# Out:
# 0     -1.312977
# 1     -1.312977
# 2     -1.312977
# 3     -1.312977
# 4     -1.312977
#          ...
# 145    1.447956
# 146    0.922064
# 147    1.053537
# 148    1.447956
# 149    0.790591
# Name: PetalWidthCm, Length: 150, dtype: float64

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex       Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531
# 6                              McCarthy, Mr. Timothy J    male  0.673285
# 10                     Sandstrom, Miss. Marguerite Rut  female  0.044986
# 11                            Bonnell, Miss. Elizabeth  female  0.723549
# ..                                                 ...     ...       ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  0.271174
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229
# 2                               Heikkinen, Miss. Laina  female  0.321438
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531
# 4                             Allen, Mr. William Henry    male  0.434531
# ..                                                 ...     ...       ...
# ...

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'].fillna('unknown')
# Out:
# 0      unknown
# 1          C85
# 2      unknown
# 3         C123
# 4      unknown
#         ...
# 886    unknown
# 887        B42
# 888    unknown
# 889       C148
# 890    unknown
# Name: Cabin, Length: 891, dtype: object

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  0.271174
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229
# 2                               Heikkinen, Miss. Laina  female  0.321438
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531
# 4                             Allen, Mr. William Henry    male  0.434531
# ..                                                 ...     ...       ...
# ...

# %%
df['Age'].fillna(np.mean(df['Age']),inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12748\3976007119.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(np.mean(df['Age']),inplace=True)

# %%
df['Age']
# Out:
# 0      0.271174
# 1      0.472229
# 2      0.321438
# 3      0.434531
# 4      0.434531
#          ...
# 886    0.334004
# 887    0.233476
# 888    0.367921
# 889    0.321438
# 890    0.396833
# Name: Age, Length: 891, dtype: float64

# %%
from sklearn.impute import SimpleImputer
s=SimpleImputer(strategy='constant',fill_value='unkown')
df[['Cabin']]=s.fit_transform(df[['Cabin']])

# %%
df["Cabin"]
# Out:
# 0      unkown
# 1         C85
# 2      unkown
# 3        C123
# 4      unkown
#         ...
# 886    unkown
# 887       B42
# 888    unkown
# 889      C148
# 890    unkown
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# ## 06/06/2025:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import RobustScaler

# %%
df1=pd.read_csv('iris.csv')

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
rs=RobustScaler()
df1['PetalLengthCm']=rs.fit_transform(df1[['PetalLengthCm']])

# %%
df1['PetalLengthCm']
# Out:
# 0     -0.842857
# 1     -0.842857
# 2     -0.871429
# 3     -0.814286
# 4     -0.842857
#          ...
# 145    0.242857
# 146    0.185714
# 147    0.242857
# 148    0.300000
# 149    0.214286
# Name: PetalLengthCm, Length: 150, dtype: float64

# %% [markdown]
# ## Encoding

# %%
1.label encoding:
we are using label encoding for ordinal data
when we have only two categories and data is nominal then we can use label encoding
if we have  more than two categories we cannot used label encoding  for catogorical data 
it will convert the categorical column into numerical column
as compare to one hot encoding label encoding is memory efficient.

# %%
df2=pd.read_csv('loan.csv')

# %%
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['Education']=le.fit_transform(df2[['Education']])
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df2['Education']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 609    0
# 610    0
# 611    0
# 612    0
# 613    0
# Name: Education, Length: 614, dtype: int32

# %%
df2.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df3=pd.read_csv('mushrooms.csv')

# %%
df3
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df3['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
le=LabelEncoder()
df3['class']=le.fit_transform(df3[['class']])
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df3['class']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
2.one encoding:
*it is also used to convert categorical data into numerical data
-it is mostly used for nominal data
-it is not memory efficient comapre to label encoding becoz it will create a separete  column for each category
syntax:
from sklearn.preprocessing import 
OneHotEncoder(sparse_output=False)

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
h=np.array([167,166,158,266])
w=np.array([67,59,78,200])
plt.scatter(h,w)
plt.show()

# %%
df=pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
plt.scatter(x=df["total_sqft"],y=df["price"])
plt.show()

# %%
df['price']
# Out:
# 0         39.07
# 1        120.00
# 2         62.00
# 3         95.00
# 4         51.00
#           ...
# 13315    231.00
# 13316    400.00
# 13317     60.00
# 13318    488.00
# 13319     17.00
# Name: price, Length: 13320, dtype: float64

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_24076\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>
