# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
mu=1
sig=0.5
sample=np.random.lognormal(mean=mu,sigma=sig,size=100)

# %%
sample
# Out:
# array([ 3.96668953,  3.34122499,  3.77786557,  4.58562727,  3.53325011,
#         3.88180186,  1.34704627,  2.4239166 ,  9.8838556 ,  2.38023044,
#         5.80924145,  7.01773572,  2.17865117,  2.542227  ,  1.1478225 ,
#         2.27006162,  2.38407708,  2.07250232,  1.39569423,  4.37544822,
#         2.41245743,  2.93531998, 10.25627077,  3.00267668,  0.96604146,
#         3.8692094 ,  1.89627436,  3.67689076,  3.18609399,  2.55975367,
#         3.03605947,  4.07689499,  3.47058176,  1.71184422,  2.1339987 ,
#         6.24679451,  1.92844508,  2.71066166,  1.15241538,  7.59584117,
#         2.80953751,  1.84886767,  1.74325309,  0.70791062,  3.28302048,
#         3.17775943,  2.8429456 ,  3.43057126,  2.26945424,  3.65144051,
#         3.19844773,  1.157044  ,  1.76290158,  1.80432302,  3.03771612,
#         3.97871375,  8.70611267,  3.44751228,  3.21760435,  2.83871228,
#         2.30445114,  4.07115857,  3.88887135,  4.1953322 ,  5.46727864,
# ...

# %%
new_sample=np.log(sample)

# %%
new_sample
# Out:
# array([ 1.37793188,  1.2063375 ,  1.32915919,  1.52292691,  1.26221816,
#         1.35629944,  0.29791425,  0.88538466,  2.29090268,  0.86719731,
#         1.75945   ,  1.94844062,  0.77870596,  0.93304047,  0.13786667,
#         0.81980698,  0.86881208,  0.72875673,  0.33339195,  1.47600896,
#         0.88064591,  1.07681647,  2.3278893 ,  1.09950412, -0.03454853,
#         1.3530502 ,  0.6398911 ,  1.30206749,  1.15879571,  0.93991103,
#         1.11056045,  1.40533567,  1.24432223,  0.53757128,  0.75799754,
#         1.83206845,  0.65671402,  0.99719276,  0.14186007,  2.02760088,
#         1.03301988,  0.61457338,  0.55575296, -0.34543744,  1.18876388,
#         1.15617637,  1.0448407 ,  1.23272679,  0.81953938,  1.29512175,
#         1.16266561,  0.14586847,  0.56696108,  0.59018546,  1.11110596,
#         1.38095859,  2.16402538,  1.23765289,  1.16863709,  1.04335053,
#         0.83484253,  1.40392762,  1.35811897,  1.43397253,  1.69878099,
# ...

# %%
a=np.log(new_sample)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11452\1821140488.py:1: RuntimeWarning: invalid value encountered in log
#   a=np.log(new_sample)

# %%
a
# Out:
# array([ 0.32058373,  0.18758891,  0.28454655,  0.42063408,  0.23287062,
#         0.30475999, -1.2109496 , -0.12173308,  0.82894592, -0.14248875,
#         0.56500126,  0.66702937, -0.25012177, -0.0693067 , -1.98146821,
#        -0.19868636, -0.14062843, -0.31641531, -1.09843647,  0.3893418 ,
#        -0.12709965,  0.07400897,  0.84496198,  0.09485928,         nan,
#         0.30236145, -0.44645728,  0.26395338,  0.14738129, -0.06197006,
#         0.1048648 ,  0.34027618,  0.21859099, -0.62069391, -0.27707514,
#         0.60544563, -0.42050664, -0.00281119, -1.95291414,  0.70685326,
#         0.03248644, -0.48682694, -0.5874314 ,         nan,  0.17291401,
#         0.14511833,  0.04386443,  0.20922862, -0.19901283,  0.25860471,
#         0.15071531, -1.92504993, -0.56746463, -0.52731844,  0.10535588,
#         0.32277789,  0.77197009,  0.21321676,  0.15583819,  0.0424372 ,
#        -0.18051216,  0.33927375,  0.30610064,  0.36044858,  0.52991093,
# ...

# %%
stats.probplot(new_sample,dist='norm',plot=plt)
# Out:
# ((array([-2.46203784, -2.12570747, -1.93122778, -1.79044653, -1.67819304,
#          -1.58381122, -1.50174123, -1.42869743, -1.36256869, -1.30191411,
#          -1.24570419, -1.19317644, -1.14374949, -1.09696931, -1.05247413,
#          -1.00997067, -0.96921765, -0.93001393, -0.89218993, -0.85560121,
#          -0.82012357, -0.78564937, -0.75208458, -0.71934648, -0.68736185,
#          -0.65606548, -0.62539893, -0.59530962, -0.56574992, -0.53667655,
#          -0.50804994, -0.47983378, -0.45199463, -0.42450149, -0.39732558,
#          -0.37044003, -0.34381966, -0.31744076, -0.29128096, -0.26531902,
#          -0.23953472, -0.21390872, -0.18842244, -0.16305799, -0.13779803,
#          -0.1126257 , -0.08752455, -0.06247843, -0.03747145, -0.01248789,
#           0.01248789,  0.03747145,  0.06247843,  0.08752455,  0.1126257 ,
#           0.13779803,  0.16305799,  0.18842244,  0.21390872,  0.23953472,
#           0.26531902,  0.29128096,  0.31744076,  0.34381966,  0.37044003,
# ...

# %%
df=pd.read_csv('haberman.csv')

# %%
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
df.shape
# Out:
# (305, 4)

# %%
df.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
df.head(5)
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.rename(columns={'30':'Age','64':'op_year','1':'Aux_nodes','1.1':'survival_status'},inplace=True)

# %%
df
# Out:
#      Age  op_year  Aux_nodes  survival_status
# 0     30       62          3                1
# 1     30       65          0                1
# 2     31       59          2                1
# 3     31       65          4                1
# 4     33       58         10                1
# ..   ...      ...        ...              ...
# 300   75       62          1                1
# 301   76       67          0                1
# 302   77       65          3                1
# 303   78       65          1                2
# 304   83       58          2                2
#
# [305 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              305 non-null    int64
#  1   op_year          305 non-null    int64
#  2   Aux_nodes        305 non-null    int64
#  3   survival_status  305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
df.describe()
# Out:
#               Age     op_year   Aux_nodes  survival_status
# count  305.000000  305.000000  305.000000       305.000000
# mean    52.531148   62.849180    4.036066         1.265574
# std     10.744024    3.254078    7.199370         0.442364
# min     30.000000   58.000000    0.000000         1.000000
# 25%     44.000000   60.000000    0.000000         1.000000
# 50%     52.000000   63.000000    1.000000         1.000000
# 75%     61.000000   66.000000    4.000000         2.000000
# max     83.000000   69.000000   52.000000         2.000000

# %%
df['survival_status'].value_counts()
# Out:
# survival_status
# 1    224
# 2     81
# Name: count, dtype: int64

# %%
df['survival_status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survival_status'>

# %%
df['survival_status'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['survival_status']=df['survival_status'].apply(lambda x:1 if x==1 else 0)

# %%
p=df['survival_status'].mean()
q=1-p
print(f'p(success)={p},p(failure={q}')
# Out:
# p(success)=0.7344262295081967,p(failure=0.2655737704918033
