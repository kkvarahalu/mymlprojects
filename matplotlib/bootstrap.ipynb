# %%
import numpy as np

# %%
def empirical_bootstrap(data,k,k_size,c):
    median=[]
    for i in range(k):
        s=np.random.choice(data,size=k_size,replace=True)
        median.append(np.median(s))
    median.sort()
    low=(100-c)/2
    high=low+c
    return np.percentile(median,low),np.percentile(median,high)
data=[158,155,167,166,164,170,176,178,180,184]
k=1000
k_size=5
c=80
print(
