# %% [markdown]
# # 14/04/25

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv("laptop_data.csv")

# %%
a
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
a["Company"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
a["TypeName"].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(a['Price'])
plt.show()

# %%
x=[2,4,5,6,7]
y=[0,3,4,5,7]
plt.plot(x,y)

# %%
x=[2,4,5,6,7]
y=[0,3,4,5,7]
plt.bar(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('bar chart')
plt.show()

# %%
x=[3,4,6,7,8]
y=[2,4,6,7,9]
plt.title('plot between x vs y')
plt.xlabel('number')
plt.ylabel('squares')
plt.plot(x,y)

# %%
plt.plot([3,4,5,6,7])
plt.ylabel('y_axis')
plt.xlabel('x_axis')
plt.title('plot')
plt.show()

# %% [markdown]
# # 15/04/25

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
plt.plot([2,3,4,5,6],[4,5,6,7,8])
plt.xlabel("numbers")
plt.ylabel("squares")
plt.title("numbers and squares")
plt.grid()
plt.show()

# %%
a=np.arange(20)
b=np.arange(1,40,2)
plt.plot(a,b)
plt.grid()
plt.show()

# %%
x=[2,3,4,5,6]
y=[3,4,7,9,8]
plt.plot(x,y,linewidth=10.0)
plt.show()

# %%
sns.lineplot(x=x,y=y)
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("x vs y")
plt.show()

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df["Company"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
df["Cpu"].value_counts().plot(kind='bar')
plt.xticks(rotation='vertical')
plt.show()

# %%
df["OpSys"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
x=[3,4,5,6,7,6]
y=[1,3,5,6,7,8]
plt.bar(x,y)
plt.xlabel('x_axis')
plt.ylabel('y_axis')
plt.show()

# %%
h=[3,4,5,6,7]
dia=[4,5,6,7,8]
plt.scatter(h,dia)
plt.show()

# %%
df1=pd.read_csv("iris.csv")

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.scatterplot(x=df1["SepalLengthCm"],y=df1["SepalWidthCm"])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
sns.barplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
sns.barplot(x=df["Company"],y=df1["Species"])
# Out:
# <Axes: xlabel='Company', ylabel='Species'>

# %%
c={
    "catageroy":['a','b','c','d'],
    "count":[2,3,4,5]
}

# %%
s=pd.DataFrame(c)

# %%
s
# Out:
#   catageroy  count
# 0         a      2
# 1         b      3
# 2         c      4
# 3         d      5

# %%
sns.countplot(x=s['catageroy'],data=s)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
a["Price"].value_counts().plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # 16/04/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot([1,2,3,4,5])
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]
sns.lineplot(x=x,y=y)
plt.show()

# %%
e=pd.read_csv("laptop_data.csv")

# %%
e['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
e.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
e['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
x=[1,2,3,4,5]
y=[3,4,5,6,7]
sns.barplot(x=x,y=y)
plt.show()

# %%
sns.countplot(x=e['Price'],data=e)
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.countplot(x=e['Company'],data=e)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=e['Company'],y=e['Price'],data=e)
plt.xticks(rotation='vertical')
plt.show()

# %%
e=pd.DataFrame({"category":['A','A','B','B','C','C','A','B','C'],
               "values":[11,12,34,56,78,99,100,12,1]
               })

# %%
e
# Out:
#   category  values
# 0        A      11
# 1        A      12
# 2        B      34
# 3        B      56
# 4        C      78
# 5        C      99
# 6        A     100
# 7        B      12
# 8        C       1

# %%
sns.boxplot(x=e['category'],y=e['values'],data=e)
# Out:
# <Axes: xlabel='category', ylabel='values'>

# %%
d=pd.read_csv("laptop_data.csv")

# %%
sns.distplot(d['Price'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19008\2295455881.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# # 17/04/2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
r=pd.read_csv("iris.csv")

# %%
r
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
r['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
c=r[r['Species']=='Iris-setosa']

# %%
c
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
c['SepalLengthCm'].mean()
# Out:
# 5.006

# %%
s=r[r['Species']=='Iris-versicolor']

# %%
s
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
x=r['SepalLengthCm'].mean()

# %%
x
# Out:
# 5.843333333333334

# %%
sns.boxplot(x=r['Species'],y=r['SepalLengthCm'],data=r)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x=r['Species'],y=r['PetalLengthCm'],data=r)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
# Habermans cancer survival dataset
